# %%
from model_utils import *
import librosa
import librosa.display
import os
import numpy as np
import glob

# %%
project_dir = r'D:/Sistemas de Informação/TCC/'
#project_dir = os.path.dirname(os.path.abspath(__file__))
data_dir = project_dir+'data/'
audioset_indices_csv = project_dir+'segments/subset_class_labels_indices.csv'
footstep_data = data_dir+'train/footstep_data'
other_data = data_dir+'train/other_data'

train_data = data_dir+'train/train_data'
train_csv = project_dir+ 'segments/2400_subset_unbalanced_train_segments.csv'

audioset_eval_csv = project_dir+'segments/subset_eval_segments.csv'
eval_sub_dir = 'eval/audio'

# %%
count = 0
for fn in natural_sort(glob.glob(os.path.join(data_dir, train_data, "*.wav"))):
        # Need to get the labels for each clip from the CSV file
        prefix = os.path.basename(str(count)+'_')
        os.rename(os.path.join(train_data, fn), os.path.join(train_data, "{}_{}".format(prefix, fn.split(train_data)[1].split('\\')[1])))
        count +=1

# %%
# hiperparâmetros para extração de características
frames = 420 # largura do mel spectogram 
bands = 60 # altura

# %%
def extract_features(parent_dir,sub_dir,csv_file,file_ext="*.wav",bands = 60,frames = 420):
    log_specgrams = np.empty((0, bands,frames))
    file_labels = []
    count = 0
    for fn in natural_sort(glob.glob(os.path.join(parent_dir, sub_dir, file_ext))):
        sound_clip, s = librosa.load(fn)
        print('Processing Line #' + str(count))
        print('features for ' + fn + ' extracted.') 
        signal = sound_clip
        melspec = librosa.feature.melspectrogram(sound_clip, sr=22050, n_fft=1024, hop_length=512, n_mels = bands)
        logspec = librosa.power_to_db(melspec)
        #log_specgrams.append(logspec)
        logspec = librosa.util.fix_length(logspec, frames)
        log_specgrams = np.append(log_specgrams, [logspec], axis=0) 
        #prefix = str(row)+'_'
        # Need to get the labels for each clip from the CSV file
        #file = fn.split(sub_dir)[1].split('\\')[1].split('_')[0]
        #os.rename(os.path.join(sub_dir, fn), os.path.join(sub_dir, "{}_{}".format(prefix, fn)))
        
        rownum = fn.split(sub_dir)[1].split('\\')[1].split('_')[0]
        print('rownum = ' + str(rownum))
        #continue
        labels = (get_file_name_labels_from_audioset_csv(rownum,csv_file,audioset_indices_csv))
        
        #print('Labels = '+str(labels))
        file_labels.append(labels)
        
        
        count += 1
        
    log_specgrams = np.array(log_specgrams)
    
    return np.array(log_specgrams), np.array(file_labels)

# %%
## já que estamos aqui, vamos Extrair features do balanced dataset também

features, labels = extract_features(data_dir,train_data,train_csv,"*.wav",bands,frames)
save_dir = data_dir+"train/train_data"+"/features/"
assure_path_exists(save_dir)
save_files(save_dir,features,labels)
# Out:
# Processing Line #0
# features for D:/Sistemas de Informação/TCC/data/train/train_data\0__0-CQl5M8keg.wav extracted.
# rownum = 0
# Processing Line #1
# features for D:/Sistemas de Informação/TCC/data/train/train_data\1__0_2kpLDJM6w.wav extracted.
# rownum = 1
# Processing Line #2
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2__0_gyUQkLCY8.wav extracted.
# rownum = 2
# Processing Line #3
# features for D:/Sistemas de Informação/TCC/data/train/train_data\3__0a7iOLGkgTo.wav extracted.
# rownum = 3
# Processing Line #4
# features for D:/Sistemas de Informação/TCC/data/train/train_data\4__0A9_26DKhXw.wav extracted.
# rownum = 4
# Processing Line #5
# features for D:/Sistemas de Informação/TCC/data/train/train_data\5__0afvvL9CNOM.wav extracted.
# rownum = 5
# Processing Line #6
# features for D:/Sistemas de Informação/TCC/data/train/train_data\6__0Ai4NWwVH1s.wav extracted.
# rownum = 6
# Processing Line #7
# features for D:/Sistemas de Informação/TCC/data/train/train_data\7__0ANdbdSRzNk.wav extracted.
# rownum = 7
# Processing Line #8
# features for D:/Sistemas de Informação/TCC/data/train/train_data\8__0apHVAggQhk.wav extracted.
# rownum = 8
# Processing Line #9
# features for D:/Sistemas de Informação/TCC/data/train/train_data\9__0AuCSM3lekc.wav extracted.
# rownum = 9
# Processing Line #10
# features for D:/Sistemas de Informação/TCC/data/train/train_data\10__0auggfRpwg8.wav extracted.
# rownum = 10
# Processing Line #11
# features for D:/Sistemas de Informação/TCC/data/train/train_data\11__0b6Z4EVGN2c.wav extracted.
# rownum = 11
# Processing Line #12
# features for D:/Sistemas de Informação/TCC/data/train/train_data\12__0b8llx0TaiI.wav extracted.
# rownum = 12
# Processing Line #13
# features for D:/Sistemas de Informação/TCC/data/train/train_data\13__0b65Uoe7cEM.wav extracted.
# rownum = 13
# Processing Line #14
# features for D:/Sistemas de Informação/TCC/data/train/train_data\14__0B-95JugHlY.wav extracted.
# rownum = 14
# Processing Line #15
# features for D:/Sistemas de Informação/TCC/data/train/train_data\15__0b-TVUxTq_w.wav extracted.
# rownum = 15
# Processing Line #16
# features for D:/Sistemas de Informação/TCC/data/train/train_data\16__0bGmMu5fYlg.wav extracted.
# rownum = 16
# Processing Line #17
# features for D:/Sistemas de Informação/TCC/data/train/train_data\17__0Bhr5qOwyO4.wav extracted.
# rownum = 17
# Processing Line #18
# features for D:/Sistemas de Informação/TCC/data/train/train_data\18__0Bomd1Tm9i4.wav extracted.
# rownum = 18
# Processing Line #19
# features for D:/Sistemas de Informação/TCC/data/train/train_data\19__0bovQBIUZho.wav extracted.
# rownum = 19
# Processing Line #20
# features for D:/Sistemas de Informação/TCC/data/train/train_data\20__0bqq8bOkqlQ.wav extracted.
# rownum = 20
# Processing Line #21
# features for D:/Sistemas de Informação/TCC/data/train/train_data\21__0c2-O46WVAc.wav extracted.
# rownum = 21
# Processing Line #22
# features for D:/Sistemas de Informação/TCC/data/train/train_data\22__0cTU36bzIEw.wav extracted.
# rownum = 22
# Processing Line #23
# features for D:/Sistemas de Informação/TCC/data/train/train_data\23__0CU6ZLqtPxE.wav extracted.
# rownum = 23
# Processing Line #24
# features for D:/Sistemas de Informação/TCC/data/train/train_data\24__0CVDMvWy2Oo.wav extracted.
# rownum = 24
# Processing Line #25
# features for D:/Sistemas de Informação/TCC/data/train/train_data\25__0CY7lKyomNk.wav extracted.
# rownum = 25
# Processing Line #26
# features for D:/Sistemas de Informação/TCC/data/train/train_data\26__0D8poBxIt40.wav extracted.
# rownum = 26
# Processing Line #27
# features for D:/Sistemas de Informação/TCC/data/train/train_data\27__0d9m7GbfOd0.wav extracted.
# rownum = 27
# Processing Line #28
# features for D:/Sistemas de Informação/TCC/data/train/train_data\28__0d-Z3sfHN7c.wav extracted.
# rownum = 28
# Processing Line #29
# features for D:/Sistemas de Informação/TCC/data/train/train_data\29__0dIuvs4jmqw.wav extracted.
# rownum = 29
# Processing Line #30
# features for D:/Sistemas de Informação/TCC/data/train/train_data\30__0djKVcWNt0c.wav extracted.
# rownum = 30
# Processing Line #31
# features for D:/Sistemas de Informação/TCC/data/train/train_data\31__0Dly8-eZvyE.wav extracted.
# rownum = 31
# Processing Line #32
# features for D:/Sistemas de Informação/TCC/data/train/train_data\32__0dOzNG6keS8.wav extracted.
# rownum = 32
# Processing Line #33
# features for D:/Sistemas de Informação/TCC/data/train/train_data\33__0EymGuYWkFk.wav extracted.
# rownum = 33
# Processing Line #34
# features for D:/Sistemas de Informação/TCC/data/train/train_data\34__0fAbkEnK2z0.wav extracted.
# rownum = 34
# Processing Line #35
# features for D:/Sistemas de Informação/TCC/data/train/train_data\35__0FOF4zyWRFY.wav extracted.
# rownum = 35
# Processing Line #36
# features for D:/Sistemas de Informação/TCC/data/train/train_data\36__0fq17k08JyM.wav extracted.
# rownum = 36
# Processing Line #37
# features for D:/Sistemas de Informação/TCC/data/train/train_data\37__0G1vMovVunM.wav extracted.
# rownum = 37
# Processing Line #38
# features for D:/Sistemas de Informação/TCC/data/train/train_data\38__0g69PZWg0c0.wav extracted.
# rownum = 38
# Processing Line #39
# features for D:/Sistemas de Informação/TCC/data/train/train_data\39__0gIL9-d-tAE.wav extracted.
# rownum = 39
# Processing Line #40
# features for D:/Sistemas de Informação/TCC/data/train/train_data\40__0gJNHE-3jdc.wav extracted.
# rownum = 40
# Processing Line #41
# features for D:/Sistemas de Informação/TCC/data/train/train_data\41__0Gjr5IQTCfA.wav extracted.
# rownum = 41
# Processing Line #42
# features for D:/Sistemas de Informação/TCC/data/train/train_data\42__0GkHFXdTXbs.wav extracted.
# rownum = 42
# Processing Line #43
# features for D:/Sistemas de Informação/TCC/data/train/train_data\43__0Gogi_R6IfQ.wav extracted.
# rownum = 43
# Processing Line #44
# features for D:/Sistemas de Informação/TCC/data/train/train_data\44__0gOWgN0zF6c.wav extracted.
# rownum = 44
# Processing Line #45
# features for D:/Sistemas de Informação/TCC/data/train/train_data\45__0gPDnn-7Glk.wav extracted.
# rownum = 45
# Processing Line #46
# features for D:/Sistemas de Informação/TCC/data/train/train_data\46__0gTVF89ieAI.wav extracted.
# rownum = 46
# Processing Line #47
# features for D:/Sistemas de Informação/TCC/data/train/train_data\47__0hBbMIsD1rQ.wav extracted.
# rownum = 47
# Processing Line #48
# features for D:/Sistemas de Informação/TCC/data/train/train_data\48__0HDqQf2I620.wav extracted.
# rownum = 48
# Processing Line #49
# features for D:/Sistemas de Informação/TCC/data/train/train_data\49__0hqdD8AlQ4o.wav extracted.
# rownum = 49
# Processing Line #50
# features for D:/Sistemas de Informação/TCC/data/train/train_data\50__0i0dC-LXgqk.wav extracted.
# rownum = 50
# Processing Line #51
# features for D:/Sistemas de Informação/TCC/data/train/train_data\51__00IHLCAuQdg.wav extracted.
# rownum = 51
# Processing Line #52
# features for D:/Sistemas de Informação/TCC/data/train/train_data\52__0ISbQYn4M5A.wav extracted.
# rownum = 52
# Processing Line #53
# features for D:/Sistemas de Informação/TCC/data/train/train_data\53__0iYTcE9ca80.wav extracted.
# rownum = 53
# Processing Line #54
# features for D:/Sistemas de Informação/TCC/data/train/train_data\54__0iZLsGa-bts.wav extracted.
# rownum = 54
# Processing Line #55
# features for D:/Sistemas de Informação/TCC/data/train/train_data\55__0J9iaLKS3xQ.wav extracted.
# rownum = 55
# Processing Line #56
# features for D:/Sistemas de Informação/TCC/data/train/train_data\56__0JLPQl6On-E.wav extracted.
# rownum = 56
# Processing Line #57
# features for D:/Sistemas de Informação/TCC/data/train/train_data\57__0JOdbnmi_Og.wav extracted.
# rownum = 57
# Processing Line #58
# features for D:/Sistemas de Informação/TCC/data/train/train_data\58__0jwmBcHrCAM.wav extracted.
# rownum = 58
# Processing Line #59
# features for D:/Sistemas de Informação/TCC/data/train/train_data\59__0kLIW7FUFCY.wav extracted.
# rownum = 59
# Processing Line #60
# features for D:/Sistemas de Informação/TCC/data/train/train_data\60__0KR-Mj4zwAA.wav extracted.
# rownum = 60
# Processing Line #61
# features for D:/Sistemas de Informação/TCC/data/train/train_data\61__0l1acpkziXE.wav extracted.
# rownum = 61
# Processing Line #62
# features for D:/Sistemas de Informação/TCC/data/train/train_data\62__0L9F7PAINqo.wav extracted.
# rownum = 62
# Processing Line #63
# features for D:/Sistemas de Informação/TCC/data/train/train_data\63__0laGkteFLrE.wav extracted.
# rownum = 63
# Processing Line #64
# features for D:/Sistemas de Informação/TCC/data/train/train_data\64__0lhxRnHx5l8.wav extracted.
# rownum = 64
# Processing Line #65
# features for D:/Sistemas de Informação/TCC/data/train/train_data\65__0lJvlbYgnRY.wav extracted.
# rownum = 65
# Processing Line #66
# features for D:/Sistemas de Informação/TCC/data/train/train_data\66__0LRVEjRzlQY.wav extracted.
# rownum = 66
# Processing Line #67
# features for D:/Sistemas de Informação/TCC/data/train/train_data\67__0LwET4zc4Uo.wav extracted.
# rownum = 67
# Processing Line #68
# features for D:/Sistemas de Informação/TCC/data/train/train_data\68__0M9He7yxJeI.wav extracted.
# rownum = 68
# Processing Line #69
# features for D:/Sistemas de Informação/TCC/data/train/train_data\69__0McMX24F8bc.wav extracted.
# rownum = 69
# Processing Line #70
# features for D:/Sistemas de Informação/TCC/data/train/train_data\70__0mhFsYWUTIQ.wav extracted.
# rownum = 70
# Processing Line #71
# features for D:/Sistemas de Informação/TCC/data/train/train_data\71__0MvUsyev20Y.wav extracted.
# rownum = 71
# Processing Line #72
# features for D:/Sistemas de Informação/TCC/data/train/train_data\72__0MxiJUoi7ko.wav extracted.
# rownum = 72
# Processing Line #73
# features for D:/Sistemas de Informação/TCC/data/train/train_data\73__0NGVdTv1zTo.wav extracted.
# rownum = 73
# Processing Line #74
# features for D:/Sistemas de Informação/TCC/data/train/train_data\74__0NxqgIaIlJU.wav extracted.
# rownum = 74
# Processing Line #75
# features for D:/Sistemas de Informação/TCC/data/train/train_data\75__0O3lW5g6D1A.wav extracted.
# rownum = 75
# Processing Line #76
# features for D:/Sistemas de Informação/TCC/data/train/train_data\76__0o96Y87yXiU.wav extracted.
# rownum = 76
# Processing Line #77
# features for D:/Sistemas de Informação/TCC/data/train/train_data\77__0OgOXzLvX3o.wav extracted.
# rownum = 77
# Processing Line #78
# features for D:/Sistemas de Informação/TCC/data/train/train_data\78__0otlgpTbbCU.wav extracted.
# rownum = 78
# Processing Line #79
# features for D:/Sistemas de Informação/TCC/data/train/train_data\79__0OUWTyO45Lc.wav extracted.
# rownum = 79
# Processing Line #80
# features for D:/Sistemas de Informação/TCC/data/train/train_data\80__0p3K2WyARgA.wav extracted.
# rownum = 80
# Processing Line #81
# features for D:/Sistemas de Informação/TCC/data/train/train_data\81__0P4pBhboTlI.wav extracted.
# rownum = 81
# Processing Line #82
# features for D:/Sistemas de Informação/TCC/data/train/train_data\82__0PbImn6M0hw.wav extracted.
# rownum = 82
# Processing Line #83
# features for D:/Sistemas de Informação/TCC/data/train/train_data\83__0Pc8auKSTbc.wav extracted.
# rownum = 83
# Processing Line #84
# features for D:/Sistemas de Informação/TCC/data/train/train_data\84__0pluHgw_0GA.wav extracted.
# rownum = 84
# Processing Line #85
# features for D:/Sistemas de Informação/TCC/data/train/train_data\85__0PnVsLcudEQ.wav extracted.
# rownum = 85
# Processing Line #86
# features for D:/Sistemas de Informação/TCC/data/train/train_data\86__0pqU9_sA1Ds.wav extracted.
# rownum = 86
# Processing Line #87
# features for D:/Sistemas de Informação/TCC/data/train/train_data\87__0pSTPUlwm6M.wav extracted.
# rownum = 87
# Processing Line #88
# features for D:/Sistemas de Informação/TCC/data/train/train_data\88__0PuND_G8VVQ.wav extracted.
# rownum = 88
# Processing Line #89
# features for D:/Sistemas de Informação/TCC/data/train/train_data\89__0PX1ax-Ce98.wav extracted.
# rownum = 89
# Processing Line #90
# features for D:/Sistemas de Informação/TCC/data/train/train_data\90__0q6wn4cIrwY.wav extracted.
# rownum = 90
# Processing Line #91
# features for D:/Sistemas de Informação/TCC/data/train/train_data\91__0qes0wPqdEs.wav extracted.
# rownum = 91
# Processing Line #92
# features for D:/Sistemas de Informação/TCC/data/train/train_data\92__0QOYirw4e3I.wav extracted.
# rownum = 92
# Processing Line #93
# features for D:/Sistemas de Informação/TCC/data/train/train_data\93__0qQIQ624M7s.wav extracted.
# rownum = 93
# Processing Line #94
# features for D:/Sistemas de Informação/TCC/data/train/train_data\94__0qRAl16xx7s.wav extracted.
# rownum = 94
# Processing Line #95
# features for D:/Sistemas de Informação/TCC/data/train/train_data\95__0RE1oid4DWI.wav extracted.
# rownum = 95
# Processing Line #96
# features for D:/Sistemas de Informação/TCC/data/train/train_data\96__0rEOa-gu4jk.wav extracted.
# rownum = 96
# Processing Line #97
# features for D:/Sistemas de Informação/TCC/data/train/train_data\97__0rziEm3pirA.wav extracted.
# rownum = 97
# Processing Line #98
# features for D:/Sistemas de Informação/TCC/data/train/train_data\98__0S82W-pLaV8.wav extracted.
# rownum = 98
# Processing Line #99
# features for D:/Sistemas de Informação/TCC/data/train/train_data\99__0SIdWwVwhWw.wav extracted.
# rownum = 99
# Processing Line #100
# features for D:/Sistemas de Informação/TCC/data/train/train_data\100__0sRWi1RejRs.wav extracted.
# rownum = 100
# Processing Line #101
# features for D:/Sistemas de Informação/TCC/data/train/train_data\101__0STEbIygynI.wav extracted.
# rownum = 101
# Processing Line #102
# features for D:/Sistemas de Informação/TCC/data/train/train_data\102__0SvMvRk9CQY.wav extracted.
# rownum = 102
# Processing Line #103
# features for D:/Sistemas de Informação/TCC/data/train/train_data\103__0syAoR0m1bA.wav extracted.
# rownum = 103
# Processing Line #104
# features for D:/Sistemas de Informação/TCC/data/train/train_data\104__000T_9H5mLM.wav extracted.
# rownum = 104
# Processing Line #105
# features for D:/Sistemas de Informação/TCC/data/train/train_data\105__0TeYskXhwbM.wav extracted.
# rownum = 105
# Processing Line #106
# features for D:/Sistemas de Informação/TCC/data/train/train_data\106__0TgNW1DdffE.wav extracted.
# rownum = 106
# Processing Line #107
# features for D:/Sistemas de Informação/TCC/data/train/train_data\107__0tMW8Q0YClg.wav extracted.
# rownum = 107
# Processing Line #108
# features for D:/Sistemas de Informação/TCC/data/train/train_data\108__0u5MX8zZn7U.wav extracted.
# rownum = 108
# Processing Line #109
# features for D:/Sistemas de Informação/TCC/data/train/train_data\109__0UarDUuwZg8.wav extracted.
# rownum = 109
# Processing Line #110
# features for D:/Sistemas de Informação/TCC/data/train/train_data\110__0Uj7tVjkDsE.wav extracted.
# rownum = 110
# Processing Line #111
# features for D:/Sistemas de Informação/TCC/data/train/train_data\111__0UkvXtfvqag.wav extracted.
# rownum = 111
# Processing Line #112
# features for D:/Sistemas de Informação/TCC/data/train/train_data\112__0UNognEVGB8.wav extracted.
# rownum = 112
# Processing Line #113
# features for D:/Sistemas de Informação/TCC/data/train/train_data\113__0UsG8ThIj3Q.wav extracted.
# rownum = 113
# Processing Line #114
# features for D:/Sistemas de Informação/TCC/data/train/train_data\114__0uuCpTLL594.wav extracted.
# rownum = 114
# Processing Line #115
# features for D:/Sistemas de Informação/TCC/data/train/train_data\115__0vjFeXhyh1U.wav extracted.
# rownum = 115
# Processing Line #116
# features for D:/Sistemas de Informação/TCC/data/train/train_data\116__0vQY_wPclWw.wav extracted.
# rownum = 116
# Processing Line #117
# features for D:/Sistemas de Informação/TCC/data/train/train_data\117__0VwRpuGNnWk.wav extracted.
# rownum = 117
# Processing Line #118
# features for D:/Sistemas de Informação/TCC/data/train/train_data\118__0vxVj6yaGg0.wav extracted.
# rownum = 118
# Processing Line #119
# features for D:/Sistemas de Informação/TCC/data/train/train_data\119__0WaYk_XqITE.wav extracted.
# rownum = 119
# Processing Line #120
# features for D:/Sistemas de Informação/TCC/data/train/train_data\120__0wMfygv6tSU.wav extracted.
# rownum = 120
# Processing Line #121
# features for D:/Sistemas de Informação/TCC/data/train/train_data\121__0wMP3oq6-Uc.wav extracted.
# rownum = 121
# Processing Line #122
# features for D:/Sistemas de Informação/TCC/data/train/train_data\122__0WrB-HjwqEU.wav extracted.
# rownum = 122
# Processing Line #123
# features for D:/Sistemas de Informação/TCC/data/train/train_data\123__0WyJY8yowa4.wav extracted.
# rownum = 123
# Processing Line #124
# features for D:/Sistemas de Informação/TCC/data/train/train_data\124__0xJ0msAYDps.wav extracted.
# rownum = 124
# Processing Line #125
# features for D:/Sistemas de Informação/TCC/data/train/train_data\125__0Xk215fYieE.wav extracted.
# rownum = 125
# Processing Line #126
# features for D:/Sistemas de Informação/TCC/data/train/train_data\126__0XufL2-GLR0.wav extracted.
# rownum = 126
# Processing Line #127
# features for D:/Sistemas de Informação/TCC/data/train/train_data\127__0y-vWZWCMJM.wav extracted.
# rownum = 127
# Processing Line #128
# features for D:/Sistemas de Informação/TCC/data/train/train_data\128__0y_8qBo3aHE.wav extracted.
# rownum = 128
# Processing Line #129
# features for D:/Sistemas de Informação/TCC/data/train/train_data\129__0YnOMAls83g.wav extracted.
# rownum = 129
# Processing Line #130
# features for D:/Sistemas de Informação/TCC/data/train/train_data\130__0yVxbECDY8A.wav extracted.
# rownum = 130
# Processing Line #131
# features for D:/Sistemas de Informação/TCC/data/train/train_data\131__00ZKNyiLGP4.wav extracted.
# rownum = 131
# Processing Line #132
# features for D:/Sistemas de Informação/TCC/data/train/train_data\132__0zn46DM_mVA.wav extracted.
# rownum = 132
# Processing Line #133
# features for D:/Sistemas de Informação/TCC/data/train/train_data\133__0ZQ2TcVm4i0.wav extracted.
# rownum = 133
# Processing Line #134
# features for D:/Sistemas de Informação/TCC/data/train/train_data\134__1-Qg-02BQ70.wav extracted.
# rownum = 134
# Processing Line #135
# features for D:/Sistemas de Informação/TCC/data/train/train_data\135__1-VpPGGKcO0.wav extracted.
# rownum = 135
# Processing Line #136
# features for D:/Sistemas de Informação/TCC/data/train/train_data\136__1-ze0TUeSC4.wav extracted.
# rownum = 136
# Processing Line #137
# features for D:/Sistemas de Informação/TCC/data/train/train_data\137__1_A742sRonE.wav extracted.
# rownum = 137
# Processing Line #138
# features for D:/Sistemas de Informação/TCC/data/train/train_data\138__1_iRBeS-0nM.wav extracted.
# rownum = 138
# Processing Line #139
# features for D:/Sistemas de Informação/TCC/data/train/train_data\139__1_uV80FEB78.wav extracted.
# rownum = 139
# Processing Line #140
# features for D:/Sistemas de Informação/TCC/data/train/train_data\140__1_vtHlBEdWk.wav extracted.
# rownum = 140
# Processing Line #141
# features for D:/Sistemas de Informação/TCC/data/train/train_data\141__1a_IHFaIC3I.wav extracted.
# rownum = 141
# Processing Line #142
# features for D:/Sistemas de Informação/TCC/data/train/train_data\142__1ACKLwRs1oc.wav extracted.
# rownum = 142
# Processing Line #143
# features for D:/Sistemas de Informação/TCC/data/train/train_data\143__1ahioeszt5Q.wav extracted.
# rownum = 143
# Processing Line #144
# features for D:/Sistemas de Informação/TCC/data/train/train_data\144__1asrtwjNkdo.wav extracted.
# rownum = 144
# Processing Line #145
# features for D:/Sistemas de Informação/TCC/data/train/train_data\145__1AXjgucDtO0.wav extracted.
# rownum = 145
# Processing Line #146
# features for D:/Sistemas de Informação/TCC/data/train/train_data\146__1b5v08if3pc.wav extracted.
# rownum = 146
# Processing Line #147
# features for D:/Sistemas de Informação/TCC/data/train/train_data\147__1b311I6P3Ks.wav extracted.
# rownum = 147
# Processing Line #148
# features for D:/Sistemas de Informação/TCC/data/train/train_data\148__1bmfOrxJ8Sg.wav extracted.
# rownum = 148
# Processing Line #149
# features for D:/Sistemas de Informação/TCC/data/train/train_data\149__1bOXPrzHVlc.wav extracted.
# rownum = 149
# Processing Line #150
# features for D:/Sistemas de Informação/TCC/data/train/train_data\150__1bprWJd75oE.wav extracted.
# rownum = 150
# Processing Line #151
# features for D:/Sistemas de Informação/TCC/data/train/train_data\151__1bvy7bhRq5U.wav extracted.
# rownum = 151
# Processing Line #152
# features for D:/Sistemas de Informação/TCC/data/train/train_data\152__1bx-V87uHh0.wav extracted.
# rownum = 152
# Processing Line #153
# features for D:/Sistemas de Informação/TCC/data/train/train_data\153__1bZ93vHTa1M.wav extracted.
# rownum = 153
# Processing Line #154
# features for D:/Sistemas de Informação/TCC/data/train/train_data\154__1cBS2EG9Z9Q.wav extracted.
# rownum = 154
# Processing Line #155
# features for D:/Sistemas de Informação/TCC/data/train/train_data\155__1CK1c-c-4Pk.wav extracted.
# rownum = 155
# Processing Line #156
# features for D:/Sistemas de Informação/TCC/data/train/train_data\156__1Cln0VjScQE.wav extracted.
# rownum = 156
# Processing Line #157
# features for D:/Sistemas de Informação/TCC/data/train/train_data\157__1csZfeKIXq0.wav extracted.
# rownum = 157
# Processing Line #158
# features for D:/Sistemas de Informação/TCC/data/train/train_data\158__1CzkndLdcm8.wav extracted.
# rownum = 158
# Processing Line #159
# features for D:/Sistemas de Informação/TCC/data/train/train_data\159__1d_vgEWbiAw.wav extracted.
# rownum = 159
# Processing Line #160
# features for D:/Sistemas de Informação/TCC/data/train/train_data\160__1DHDME36lbE.wav extracted.
# rownum = 160
# Processing Line #161
# features for D:/Sistemas de Informação/TCC/data/train/train_data\161__1DheHmkaw6g.wav extracted.
# rownum = 161
# Processing Line #162
# features for D:/Sistemas de Informação/TCC/data/train/train_data\162__1DOYARo3Dwc.wav extracted.
# rownum = 162
# Processing Line #163
# features for D:/Sistemas de Informação/TCC/data/train/train_data\163__1dx4NNQwG0o.wav extracted.
# rownum = 163
# Processing Line #164
# features for D:/Sistemas de Informação/TCC/data/train/train_data\164__1E8YrDxg_4g.wav extracted.
# rownum = 164
# Processing Line #165
# features for D:/Sistemas de Informação/TCC/data/train/train_data\165__1E9q1WTgjMI.wav extracted.
# rownum = 165
# Processing Line #166
# features for D:/Sistemas de Informação/TCC/data/train/train_data\166__1epJOEequKo.wav extracted.
# rownum = 166
# Processing Line #167
# features for D:/Sistemas de Informação/TCC/data/train/train_data\167__1fOWWrEd5pU.wav extracted.
# rownum = 167
# Processing Line #168
# features for D:/Sistemas de Informação/TCC/data/train/train_data\168__1fyakO8OuYk.wav extracted.
# rownum = 168
# Processing Line #169
# features for D:/Sistemas de Informação/TCC/data/train/train_data\169__1fZj2Z3lAfc.wav extracted.
# rownum = 169
# Processing Line #170
# features for D:/Sistemas de Informação/TCC/data/train/train_data\170__1G3Al7WMAbk.wav extracted.
# rownum = 170
# Processing Line #171
# features for D:/Sistemas de Informação/TCC/data/train/train_data\171__1GlK9CiuIco.wav extracted.
# rownum = 171
# Processing Line #172
# features for D:/Sistemas de Informação/TCC/data/train/train_data\172__1GTzrvKUsK8.wav extracted.
# rownum = 172
# Processing Line #173
# features for D:/Sistemas de Informação/TCC/data/train/train_data\173__1H01oQbHNUg.wav extracted.
# rownum = 173
# Processing Line #174
# features for D:/Sistemas de Informação/TCC/data/train/train_data\174__1h_deYqMjfg.wav extracted.
# rownum = 174
# Processing Line #175
# features for D:/Sistemas de Informação/TCC/data/train/train_data\175__1ht0pf9J6Qk.wav extracted.
# rownum = 175
# Processing Line #176
# features for D:/Sistemas de Informação/TCC/data/train/train_data\176__1IO9NJI20-E.wav extracted.
# rownum = 176
# Processing Line #177
# features for D:/Sistemas de Informação/TCC/data/train/train_data\177__1irCr5xGQhQ.wav extracted.
# rownum = 177
# Processing Line #178
# features for D:/Sistemas de Informação/TCC/data/train/train_data\178__1jDfYNF-RY0.wav extracted.
# rownum = 178
# Processing Line #179
# features for D:/Sistemas de Informação/TCC/data/train/train_data\179__1jHErjpu7n0.wav extracted.
# rownum = 179
# Processing Line #180
# features for D:/Sistemas de Informação/TCC/data/train/train_data\180__1Jo_RkccI-E.wav extracted.
# rownum = 180
# Processing Line #181
# features for D:/Sistemas de Informação/TCC/data/train/train_data\181__1jZ4pzssek8.wav extracted.
# rownum = 181
# Processing Line #182
# features for D:/Sistemas de Informação/TCC/data/train/train_data\182__1k1T3uo2oRM.wav extracted.
# rownum = 182
# Processing Line #183
# features for D:/Sistemas de Informação/TCC/data/train/train_data\183__1KcQvwUhsfk.wav extracted.
# rownum = 183
# Processing Line #184
# features for D:/Sistemas de Informação/TCC/data/train/train_data\184__1l3G-vAo8cQ.wav extracted.
# rownum = 184
# Processing Line #185
# features for D:/Sistemas de Informação/TCC/data/train/train_data\185__1lhO18Nn2wg.wav extracted.
# rownum = 185
# Processing Line #186
# features for D:/Sistemas de Informação/TCC/data/train/train_data\186__1Lvi9Gch9SE.wav extracted.
# rownum = 186
# Processing Line #187
# features for D:/Sistemas de Informação/TCC/data/train/train_data\187__1M6N0LbUplk.wav extracted.
# rownum = 187
# Processing Line #188
# features for D:/Sistemas de Informação/TCC/data/train/train_data\188__1MBBJxTiCEk.wav extracted.
# rownum = 188
# Processing Line #189
# features for D:/Sistemas de Informação/TCC/data/train/train_data\189__1MDPr4ahpUk.wav extracted.
# rownum = 189
# Processing Line #190
# features for D:/Sistemas de Informação/TCC/data/train/train_data\190__1MMHlvuv3YQ.wav extracted.
# rownum = 190
# Processing Line #191
# features for D:/Sistemas de Informação/TCC/data/train/train_data\191__1mqQZDZcxoY.wav extracted.
# rownum = 191
# Processing Line #192
# features for D:/Sistemas de Informação/TCC/data/train/train_data\192__1Mrv3THavHE.wav extracted.
# rownum = 192
# Processing Line #193
# features for D:/Sistemas de Informação/TCC/data/train/train_data\193__1mSHx8QIqrU.wav extracted.
# rownum = 193
# Processing Line #194
# features for D:/Sistemas de Informação/TCC/data/train/train_data\194__1n6Pexb5Rjo.wav extracted.
# rownum = 194
# Processing Line #195
# features for D:/Sistemas de Informação/TCC/data/train/train_data\195__1nG4M8X5EVM.wav extracted.
# rownum = 195
# Processing Line #196
# features for D:/Sistemas de Informação/TCC/data/train/train_data\196__1Nio-G4_RQw.wav extracted.
# rownum = 196
# Processing Line #197
# features for D:/Sistemas de Informação/TCC/data/train/train_data\197__1NIVifuIYpw.wav extracted.
# rownum = 197
# Processing Line #198
# features for D:/Sistemas de Informação/TCC/data/train/train_data\198__1nJBX5e2nfY.wav extracted.
# rownum = 198
# Processing Line #199
# features for D:/Sistemas de Informação/TCC/data/train/train_data\199__1nKIN7HkSk4.wav extracted.
# rownum = 199
# Processing Line #200
# features for D:/Sistemas de Informação/TCC/data/train/train_data\200__1O7V1uFVDuw.wav extracted.
# rownum = 200
# Processing Line #201
# features for D:/Sistemas de Informação/TCC/data/train/train_data\201__1Occr6RFeXE.wav extracted.
# rownum = 201
# Processing Line #202
# features for D:/Sistemas de Informação/TCC/data/train/train_data\202__1omm14ZmtZU.wav extracted.
# rownum = 202
# Processing Line #203
# features for D:/Sistemas de Informação/TCC/data/train/train_data\203__1oyOLXgzy70.wav extracted.
# rownum = 203
# Processing Line #204
# features for D:/Sistemas de Informação/TCC/data/train/train_data\204__1P1YDHSHy5I.wav extracted.
# rownum = 204
# Processing Line #205
# features for D:/Sistemas de Informação/TCC/data/train/train_data\205__1pdA-nM5JyE.wav extracted.
# rownum = 205
# Processing Line #206
# features for D:/Sistemas de Informação/TCC/data/train/train_data\206__1Psil9MYo04.wav extracted.
# rownum = 206
# Processing Line #207
# features for D:/Sistemas de Informação/TCC/data/train/train_data\207__1qo_9TH2rBk.wav extracted.
# rownum = 207
# Processing Line #208
# features for D:/Sistemas de Informação/TCC/data/train/train_data\208__1QTVQKreiVg.wav extracted.
# rownum = 208
# Processing Line #209
# features for D:/Sistemas de Informação/TCC/data/train/train_data\209__1quHn8wzgY8.wav extracted.
# rownum = 209
# Processing Line #210
# features for D:/Sistemas de Informação/TCC/data/train/train_data\210__1qWo_xw4YOg.wav extracted.
# rownum = 210
# Processing Line #211
# features for D:/Sistemas de Informação/TCC/data/train/train_data\211__1R53GvXZb7s.wav extracted.
# rownum = 211
# Processing Line #212
# features for D:/Sistemas de Informação/TCC/data/train/train_data\212__1rI8q5OInl4.wav extracted.
# rownum = 212
# Processing Line #213
# features for D:/Sistemas de Informação/TCC/data/train/train_data\213__01rrQCXEDAw.wav extracted.
# rownum = 213
# Processing Line #214
# features for D:/Sistemas de Informação/TCC/data/train/train_data\214__1Shu_DULw4Q.wav extracted.
# rownum = 214
# Processing Line #215
# features for D:/Sistemas de Informação/TCC/data/train/train_data\215__1sIo2ORuiys.wav extracted.
# rownum = 215
# Processing Line #216
# features for D:/Sistemas de Informação/TCC/data/train/train_data\216__1SiPSIsNVAQ.wav extracted.
# rownum = 216
# Processing Line #217
# features for D:/Sistemas de Informação/TCC/data/train/train_data\217__1sk9EPt4734.wav extracted.
# rownum = 217
# Processing Line #218
# features for D:/Sistemas de Informação/TCC/data/train/train_data\218__1SSdto2VAq8.wav extracted.
# rownum = 218
# Processing Line #219
# features for D:/Sistemas de Informação/TCC/data/train/train_data\219__1STVXNsAnxU.wav extracted.
# rownum = 219
# Processing Line #220
# features for D:/Sistemas de Informação/TCC/data/train/train_data\220__1t9NT8Hgg-8.wav extracted.
# rownum = 220
# Processing Line #221
# features for D:/Sistemas de Informação/TCC/data/train/train_data\221__1TE3ogiP_KM.wav extracted.
# rownum = 221
# Processing Line #222
# features for D:/Sistemas de Informação/TCC/data/train/train_data\222__1u9sCb9Q9yY.wav extracted.
# rownum = 222
# Processing Line #223
# features for D:/Sistemas de Informação/TCC/data/train/train_data\223__1uBQ1iikG2Q.wav extracted.
# rownum = 223
# Processing Line #224
# features for D:/Sistemas de Informação/TCC/data/train/train_data\224__1UKdsFEmXAw.wav extracted.
# rownum = 224
# Processing Line #225
# features for D:/Sistemas de Informação/TCC/data/train/train_data\225__1uodgg6hVNc.wav extracted.
# rownum = 225
# Processing Line #226
# features for D:/Sistemas de Informação/TCC/data/train/train_data\226__1utS6hfgHIg.wav extracted.
# rownum = 226
# Processing Line #227
# features for D:/Sistemas de Informação/TCC/data/train/train_data\227__1Uwy30p75IE.wav extracted.
# rownum = 227
# Processing Line #228
# features for D:/Sistemas de Informação/TCC/data/train/train_data\228__1UyJ1w1UDy4.wav extracted.
# rownum = 228
# Processing Line #229
# features for D:/Sistemas de Informação/TCC/data/train/train_data\229__1V0ivClP50Q.wav extracted.
# rownum = 229
# Processing Line #230
# features for D:/Sistemas de Informação/TCC/data/train/train_data\230__1VsuR6ITAe4.wav extracted.
# rownum = 230
# Processing Line #231
# features for D:/Sistemas de Informação/TCC/data/train/train_data\231__1wh78dz42_4.wav extracted.
# rownum = 231
# Processing Line #232
# features for D:/Sistemas de Informação/TCC/data/train/train_data\232__1WQZeK6Td_E.wav extracted.
# rownum = 232
# Processing Line #233
# features for D:/Sistemas de Informação/TCC/data/train/train_data\233__1Wz176igo-A.wav extracted.
# rownum = 233
# Processing Line #234
# features for D:/Sistemas de Informação/TCC/data/train/train_data\234__1x50pan1DqY.wav extracted.
# rownum = 234
# Processing Line #235
# features for D:/Sistemas de Informação/TCC/data/train/train_data\235__01x98K6sw-8.wav extracted.
# rownum = 235
# Processing Line #236
# features for D:/Sistemas de Informação/TCC/data/train/train_data\236__1XJMA8ON7so.wav extracted.
# rownum = 236
# Processing Line #237
# features for D:/Sistemas de Informação/TCC/data/train/train_data\237__1xTb-CeCnhA.wav extracted.
# rownum = 237
# Processing Line #238
# features for D:/Sistemas de Informação/TCC/data/train/train_data\238__1XU7Sddlqis.wav extracted.
# rownum = 238
# Processing Line #239
# features for D:/Sistemas de Informação/TCC/data/train/train_data\239__1yhjQykRmY0.wav extracted.
# rownum = 239
# Processing Line #240
# features for D:/Sistemas de Informação/TCC/data/train/train_data\240__1YiqnDJeeAw.wav extracted.
# rownum = 240
# Processing Line #241
# features for D:/Sistemas de Informação/TCC/data/train/train_data\241__01yP0bbrBhM.wav extracted.
# rownum = 241
# Processing Line #242
# features for D:/Sistemas de Informação/TCC/data/train/train_data\242__1yTbNTz0JEo.wav extracted.
# rownum = 242
# Processing Line #243
# features for D:/Sistemas de Informação/TCC/data/train/train_data\243__1YwQWFBpxEg.wav extracted.
# rownum = 243
# Processing Line #244
# features for D:/Sistemas de Informação/TCC/data/train/train_data\244__1yysn7rHdp4.wav extracted.
# rownum = 244
# Processing Line #245
# features for D:/Sistemas de Informação/TCC/data/train/train_data\245__1YZ-tr02q74.wav extracted.
# rownum = 245
# Processing Line #246
# features for D:/Sistemas de Informação/TCC/data/train/train_data\246__1Z5N1uFQRV4.wav extracted.
# rownum = 246
# Processing Line #247
# features for D:/Sistemas de Informação/TCC/data/train/train_data\247__1Z7gyLwETZc.wav extracted.
# rownum = 247
# Processing Line #248
# features for D:/Sistemas de Informação/TCC/data/train/train_data\248__1zak--ix8Mw.wav extracted.
# rownum = 248
# Processing Line #249
# features for D:/Sistemas de Informação/TCC/data/train/train_data\249__1zjWADp4JLE.wav extracted.
# rownum = 249
# Processing Line #250
# features for D:/Sistemas de Informação/TCC/data/train/train_data\250__1zyQzv020G0.wav extracted.
# rownum = 250
# Processing Line #251
# features for D:/Sistemas de Informação/TCC/data/train/train_data\251__2-ChFqEzp7I.wav extracted.
# rownum = 251
# Processing Line #252
# features for D:/Sistemas de Informação/TCC/data/train/train_data\252__2-HKjufdrc8.wav extracted.
# rownum = 252
# Processing Line #253
# features for D:/Sistemas de Informação/TCC/data/train/train_data\253__2-PhFBwwOiM.wav extracted.
# rownum = 253
# Processing Line #254
# features for D:/Sistemas de Informação/TCC/data/train/train_data\254__2-Sfpum5C1M.wav extracted.
# rownum = 254
# Processing Line #255
# features for D:/Sistemas de Informação/TCC/data/train/train_data\255__2-SqsQNZVkM.wav extracted.
# rownum = 255
# Processing Line #256
# features for D:/Sistemas de Informação/TCC/data/train/train_data\256__2_QIxGsEIzM.wav extracted.
# rownum = 256
# Processing Line #257
# features for D:/Sistemas de Informação/TCC/data/train/train_data\257__2aaRt1_z2OI.wav extracted.
# rownum = 257
# Processing Line #258
# features for D:/Sistemas de Informação/TCC/data/train/train_data\258__2AC499CFHRY.wav extracted.
# rownum = 258
# Processing Line #259
# features for D:/Sistemas de Informação/TCC/data/train/train_data\259__2AdLg2xspek.wav extracted.
# rownum = 259
# Processing Line #260
# features for D:/Sistemas de Informação/TCC/data/train/train_data\260__2aTVSeC7bww.wav extracted.
# rownum = 260
# Processing Line #261
# features for D:/Sistemas de Informação/TCC/data/train/train_data\261__2Av-N51AsfA.wav extracted.
# rownum = 261
# Processing Line #262
# features for D:/Sistemas de Informação/TCC/data/train/train_data\262__2B7o49-DnhA.wav extracted.
# rownum = 262
# Processing Line #263
# features for D:/Sistemas de Informação/TCC/data/train/train_data\263__2BamxmQamR4.wav extracted.
# rownum = 263
# Processing Line #264
# features for D:/Sistemas de Informação/TCC/data/train/train_data\264__2bcpaKT6FiY.wav extracted.
# rownum = 264
# Processing Line #265
# features for D:/Sistemas de Informação/TCC/data/train/train_data\265__2bZCAK3PH2o.wav extracted.
# rownum = 265
# Processing Line #266
# features for D:/Sistemas de Informação/TCC/data/train/train_data\266__2C4JEfzUsFY.wav extracted.
# rownum = 266
# Processing Line #267
# features for D:/Sistemas de Informação/TCC/data/train/train_data\267__2c8_6BJ3MIA.wav extracted.
# rownum = 267
# Processing Line #268
# features for D:/Sistemas de Informação/TCC/data/train/train_data\268__2cbEW7QzMOY.wav extracted.
# rownum = 268
# Processing Line #269
# features for D:/Sistemas de Informação/TCC/data/train/train_data\269__2cHg3K2K6Hw.wav extracted.
# rownum = 269
# Processing Line #270
# features for D:/Sistemas de Informação/TCC/data/train/train_data\270__2CMdPVBfm_I.wav extracted.
# rownum = 270
# Processing Line #271
# features for D:/Sistemas de Informação/TCC/data/train/train_data\271__2cnCEbUmVCc.wav extracted.
# rownum = 271
# Processing Line #272
# features for D:/Sistemas de Informação/TCC/data/train/train_data\272__2CUf1QVlaoo.wav extracted.
# rownum = 272
# Processing Line #273
# features for D:/Sistemas de Informação/TCC/data/train/train_data\273__2D3dmgsa8ZM.wav extracted.
# rownum = 273
# Processing Line #274
# features for D:/Sistemas de Informação/TCC/data/train/train_data\274__2DDOsOk--_Q.wav extracted.
# rownum = 274
# Processing Line #275
# features for D:/Sistemas de Informação/TCC/data/train/train_data\275__2di_lGe98G4.wav extracted.
# rownum = 275
# Processing Line #276
# features for D:/Sistemas de Informação/TCC/data/train/train_data\276__2DvVhq-7C44.wav extracted.
# rownum = 276
# Processing Line #277
# features for D:/Sistemas de Informação/TCC/data/train/train_data\277__2EAHVf0MmOg.wav extracted.
# rownum = 277
# Processing Line #278
# features for D:/Sistemas de Informação/TCC/data/train/train_data\278__2ED0-tb-1OQ.wav extracted.
# rownum = 278
# Processing Line #279
# features for D:/Sistemas de Informação/TCC/data/train/train_data\279__2EFjQPMmAS8.wav extracted.
# rownum = 279
# Processing Line #280
# features for D:/Sistemas de Informação/TCC/data/train/train_data\280__2EGggNr2Kp0.wav extracted.
# rownum = 280
# Processing Line #281
# features for D:/Sistemas de Informação/TCC/data/train/train_data\281__2EUEfmRC4dA.wav extracted.
# rownum = 281
# Processing Line #282
# features for D:/Sistemas de Informação/TCC/data/train/train_data\282__2Ev7_PQ7IIs.wav extracted.
# rownum = 282
# Processing Line #283
# features for D:/Sistemas de Informação/TCC/data/train/train_data\283__2FccuV13ATg.wav extracted.
# rownum = 283
# Processing Line #284
# features for D:/Sistemas de Informação/TCC/data/train/train_data\284__2fQewjZRCvQ.wav extracted.
# rownum = 284
# Processing Line #285
# features for D:/Sistemas de Informação/TCC/data/train/train_data\285__2FWPjomcgbE.wav extracted.
# rownum = 285
# Processing Line #286
# features for D:/Sistemas de Informação/TCC/data/train/train_data\286__2GRdrwROx2Y.wav extracted.
# rownum = 286
# Processing Line #287
# features for D:/Sistemas de Informação/TCC/data/train/train_data\287__2grvG-cAa9I.wav extracted.
# rownum = 287
# Processing Line #288
# features for D:/Sistemas de Informação/TCC/data/train/train_data\288__2gXN76J-Xa4.wav extracted.
# rownum = 288
# Processing Line #289
# features for D:/Sistemas de Informação/TCC/data/train/train_data\289__2H9enh-dbl4.wav extracted.
# rownum = 289
# Processing Line #290
# features for D:/Sistemas de Informação/TCC/data/train/train_data\290__2h_KRQiZR-E.wav extracted.
# rownum = 290
# Processing Line #291
# features for D:/Sistemas de Informação/TCC/data/train/train_data\291__2he1efNmT_c.wav extracted.
# rownum = 291
# Processing Line #292
# features for D:/Sistemas de Informação/TCC/data/train/train_data\292__2HeSxoRqUEY.wav extracted.
# rownum = 292
# Processing Line #293
# features for D:/Sistemas de Informação/TCC/data/train/train_data\293__2hg6NcJdew4.wav extracted.
# rownum = 293
# Processing Line #294
# features for D:/Sistemas de Informação/TCC/data/train/train_data\294__2hiemR0YsdI.wav extracted.
# rownum = 294
# Processing Line #295
# features for D:/Sistemas de Informação/TCC/data/train/train_data\295__2hSeK18uk-U.wav extracted.
# rownum = 295
# Processing Line #296
# features for D:/Sistemas de Informação/TCC/data/train/train_data\296__2hTJNeuYlME.wav extracted.
# rownum = 296
# Processing Line #297
# features for D:/Sistemas de Informação/TCC/data/train/train_data\297__2hvhwNjjmos.wav extracted.
# rownum = 297
# Processing Line #298
# features for D:/Sistemas de Informação/TCC/data/train/train_data\298__2HvpMaBHEfo.wav extracted.
# rownum = 298
# Processing Line #299
# features for D:/Sistemas de Informação/TCC/data/train/train_data\299__2I1S96YudMk.wav extracted.
# rownum = 299
# Processing Line #300
# features for D:/Sistemas de Informação/TCC/data/train/train_data\300__2I8tyxSUYrg.wav extracted.
# rownum = 300
# Processing Line #301
# features for D:/Sistemas de Informação/TCC/data/train/train_data\301__2I60f29IC6c.wav extracted.
# rownum = 301
# Processing Line #302
# features for D:/Sistemas de Informação/TCC/data/train/train_data\302__2ikhShL4Mzk.wav extracted.
# rownum = 302
# Processing Line #303
# features for D:/Sistemas de Informação/TCC/data/train/train_data\303__2IQtHrcMwak.wav extracted.
# rownum = 303
# Processing Line #304
# features for D:/Sistemas de Informação/TCC/data/train/train_data\304__2JEE2LKRt3I.wav extracted.
# rownum = 304
# Processing Line #305
# features for D:/Sistemas de Informação/TCC/data/train/train_data\305__2jLwx27aH_Q.wav extracted.
# rownum = 305
# Processing Line #306
# features for D:/Sistemas de Informação/TCC/data/train/train_data\306__2jvs_ZyDJx4.wav extracted.
# rownum = 306
# Processing Line #307
# features for D:/Sistemas de Informação/TCC/data/train/train_data\307__2JzxtBNma1o.wav extracted.
# rownum = 307
# Processing Line #308
# features for D:/Sistemas de Informação/TCC/data/train/train_data\308__2KemIPeXeyQ.wav extracted.
# rownum = 308
# Processing Line #309
# features for D:/Sistemas de Informação/TCC/data/train/train_data\309__2KGEdf_dtag.wav extracted.
# rownum = 309
# Processing Line #310
# features for D:/Sistemas de Informação/TCC/data/train/train_data\310__2kHKofwWh3M.wav extracted.
# rownum = 310
# Processing Line #311
# features for D:/Sistemas de Informação/TCC/data/train/train_data\311__2kuuwEr32YE.wav extracted.
# rownum = 311
# Processing Line #312
# features for D:/Sistemas de Informação/TCC/data/train/train_data\312__2l6RhXgJ53Q.wav extracted.
# rownum = 312
# Processing Line #313
# features for D:/Sistemas de Informação/TCC/data/train/train_data\313__2Lzmv9GExHs.wav extracted.
# rownum = 313
# Processing Line #314
# features for D:/Sistemas de Informação/TCC/data/train/train_data\314__2meFLrr0fXA.wav extracted.
# rownum = 314
# Processing Line #315
# features for D:/Sistemas de Informação/TCC/data/train/train_data\315__2mg_rHcIJBQ.wav extracted.
# rownum = 315
# Processing Line #316
# features for D:/Sistemas de Informação/TCC/data/train/train_data\316__2mHHFW4jDSE.wav extracted.
# rownum = 316
# Processing Line #317
# features for D:/Sistemas de Informação/TCC/data/train/train_data\317__2MiC1fNqWH0.wav extracted.
# rownum = 317
# Processing Line #318
# features for D:/Sistemas de Informação/TCC/data/train/train_data\318__2nAxLOiEeR0.wav extracted.
# rownum = 318
# Processing Line #319
# features for D:/Sistemas de Informação/TCC/data/train/train_data\319__02NhRyu_KUk.wav extracted.
# rownum = 319
# Processing Line #320
# features for D:/Sistemas de Informação/TCC/data/train/train_data\320__2NzPiWAkclg.wav extracted.
# rownum = 320
# Processing Line #321
# features for D:/Sistemas de Informação/TCC/data/train/train_data\321__2nzZW3n4NNw.wav extracted.
# rownum = 321
# Processing Line #322
# features for D:/Sistemas de Informação/TCC/data/train/train_data\322__2o08IeJ_ULk.wav extracted.
# rownum = 322
# Processing Line #323
# features for D:/Sistemas de Informação/TCC/data/train/train_data\323__2O_sNnApwbc.wav extracted.
# rownum = 323
# Processing Line #324
# features for D:/Sistemas de Informação/TCC/data/train/train_data\324__2okIFtIFR_E.wav extracted.
# rownum = 324
# Processing Line #325
# features for D:/Sistemas de Informação/TCC/data/train/train_data\325__2ONn5YAAE24.wav extracted.
# rownum = 325
# Processing Line #326
# features for D:/Sistemas de Informação/TCC/data/train/train_data\326__2OntWf2hdFo.wav extracted.
# rownum = 326
# Processing Line #327
# features for D:/Sistemas de Informação/TCC/data/train/train_data\327__2ou-C3tQOco.wav extracted.
# rownum = 327
# Processing Line #328
# features for D:/Sistemas de Informação/TCC/data/train/train_data\328__2oUzpwK6WlY.wav extracted.
# rownum = 328
# Processing Line #329
# features for D:/Sistemas de Informação/TCC/data/train/train_data\329__2OxDbAlXKs0.wav extracted.
# rownum = 329
# Processing Line #330
# features for D:/Sistemas de Informação/TCC/data/train/train_data\330__2ozOv9jrLCw.wav extracted.
# rownum = 330
# Processing Line #331
# features for D:/Sistemas de Informação/TCC/data/train/train_data\331__02PHE13i1LU.wav extracted.
# rownum = 331
# Processing Line #332
# features for D:/Sistemas de Informação/TCC/data/train/train_data\332__2PLneLz79Ys.wav extracted.
# rownum = 332
# Processing Line #333
# features for D:/Sistemas de Informação/TCC/data/train/train_data\333__2PPnjG0o42Q.wav extracted.
# rownum = 333
# Processing Line #334
# features for D:/Sistemas de Informação/TCC/data/train/train_data\334__2Q3pDwODaaw.wav extracted.
# rownum = 334
# Processing Line #335
# features for D:/Sistemas de Informação/TCC/data/train/train_data\335__2QpEkZyrEeU.wav extracted.
# rownum = 335
# Processing Line #336
# features for D:/Sistemas de Informação/TCC/data/train/train_data\336__2qtFJz0Cpn8.wav extracted.
# rownum = 336
# Processing Line #337
# features for D:/Sistemas de Informação/TCC/data/train/train_data\337__2quFqRZKqQ8.wav extracted.
# rownum = 337
# Processing Line #338
# features for D:/Sistemas de Informação/TCC/data/train/train_data\338__2QVqHAvcC0g.wav extracted.
# rownum = 338
# Processing Line #339
# features for D:/Sistemas de Informação/TCC/data/train/train_data\339__2ReIfv682_s.wav extracted.
# rownum = 339
# Processing Line #340
# features for D:/Sistemas de Informação/TCC/data/train/train_data\340__2Rwmoff7oSU.wav extracted.
# rownum = 340
# Processing Line #341
# features for D:/Sistemas de Informação/TCC/data/train/train_data\341__2rWnLQGuIdI.wav extracted.
# rownum = 341
# Processing Line #342
# features for D:/Sistemas de Informação/TCC/data/train/train_data\342__2RwOsjbsmQM.wav extracted.
# rownum = 342
# Processing Line #343
# features for D:/Sistemas de Informação/TCC/data/train/train_data\343__2s-itDymnag.wav extracted.
# rownum = 343
# Processing Line #344
# features for D:/Sistemas de Informação/TCC/data/train/train_data\344__2Sa8ZtMo1RQ.wav extracted.
# rownum = 344
# Processing Line #345
# features for D:/Sistemas de Informação/TCC/data/train/train_data\345__2sFuPc2yO1M.wav extracted.
# rownum = 345
# Processing Line #346
# features for D:/Sistemas de Informação/TCC/data/train/train_data\346__2SiG7kjKRxE.wav extracted.
# rownum = 346
# Processing Line #347
# features for D:/Sistemas de Informação/TCC/data/train/train_data\347__2SKxcb818Ww.wav extracted.
# rownum = 347
# Processing Line #348
# features for D:/Sistemas de Informação/TCC/data/train/train_data\348__2Spz-16ohM8.wav extracted.
# rownum = 348
# Processing Line #349
# features for D:/Sistemas de Informação/TCC/data/train/train_data\349__2SszVYJl_5M.wav extracted.
# rownum = 349
# Processing Line #350
# features for D:/Sistemas de Informação/TCC/data/train/train_data\350__2sTDsYsur4A.wav extracted.
# rownum = 350
# Processing Line #351
# features for D:/Sistemas de Informação/TCC/data/train/train_data\351__2T6w1aPGb6c.wav extracted.
# rownum = 351
# Processing Line #352
# features for D:/Sistemas de Informação/TCC/data/train/train_data\352__2tbhV5KBPbg.wav extracted.
# rownum = 352
# Processing Line #353
# features for D:/Sistemas de Informação/TCC/data/train/train_data\353__2TBWSnIjJMk.wav extracted.
# rownum = 353
# Processing Line #354
# features for D:/Sistemas de Informação/TCC/data/train/train_data\354__2thsNDqOH-E.wav extracted.
# rownum = 354
# Processing Line #355
# features for D:/Sistemas de Informação/TCC/data/train/train_data\355__2tSLXPbJA7k.wav extracted.
# rownum = 355
# Processing Line #356
# features for D:/Sistemas de Informação/TCC/data/train/train_data\356__2tta0Gb6-r0.wav extracted.
# rownum = 356
# Processing Line #357
# features for D:/Sistemas de Informação/TCC/data/train/train_data\357__2TtMSJn3m00.wav extracted.
# rownum = 357
# Processing Line #358
# features for D:/Sistemas de Informação/TCC/data/train/train_data\358__2U9j6BMzCgI.wav extracted.
# rownum = 358
# Processing Line #359
# features for D:/Sistemas de Informação/TCC/data/train/train_data\359__2UO9Q0YaXRY.wav extracted.
# rownum = 359
# Processing Line #360
# features for D:/Sistemas de Informação/TCC/data/train/train_data\360__2vmkiYq8M98.wav extracted.
# rownum = 360
# Processing Line #361
# features for D:/Sistemas de Informação/TCC/data/train/train_data\361__2vpjrOFhyic.wav extracted.
# rownum = 361
# Processing Line #362
# features for D:/Sistemas de Informação/TCC/data/train/train_data\362__2VZge2V2mkk.wav extracted.
# rownum = 362
# Processing Line #363
# features for D:/Sistemas de Informação/TCC/data/train/train_data\363__2WPwKigBCTI.wav extracted.
# rownum = 363
# Processing Line #364
# features for D:/Sistemas de Informação/TCC/data/train/train_data\364__2wYIy9Osu-I.wav extracted.
# rownum = 364
# Processing Line #365
# features for D:/Sistemas de Informação/TCC/data/train/train_data\365__2wzUmr0idBo.wav extracted.
# rownum = 365
# Processing Line #366
# features for D:/Sistemas de Informação/TCC/data/train/train_data\366__2X3649Grt1E.wav extracted.
# rownum = 366
# Processing Line #367
# features for D:/Sistemas de Informação/TCC/data/train/train_data\367__2xd-w73FEho.wav extracted.
# rownum = 367
# Processing Line #368
# features for D:/Sistemas de Informação/TCC/data/train/train_data\368__2xekWIJOJ04.wav extracted.
# ...
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2292__Y9QCAAeCZ7c.wav extracted.
# rownum = 2292
# Processing Line #2293
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2293__Y24KxWkeWdk.wav extracted.
# rownum = 2293
# Processing Line #2294
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2294__Y31Vr5Mwhtg.wav extracted.
# rownum = 2294
# Processing Line #2295
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2295__y_Ciz5Z2nnY.wav extracted.
# rownum = 2295
# Processing Line #2296
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2296__Y_GP5irz4YA.wav extracted.
# rownum = 2296
# Processing Line #2297
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2297__ya2eRJFU6sE.wav extracted.
# rownum = 2297
# Processing Line #2298
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2298__yaR7agkcywc.wav extracted.
# rownum = 2298
# Processing Line #2299
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2299__Ybd1-i487fs.wav extracted.
# rownum = 2299
# Processing Line #2300
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2300__YbLED_wD3Jc.wav extracted.
# rownum = 2300
# Processing Line #2301
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2301__YcDLlhDUo-0.wav extracted.
# rownum = 2301
# Processing Line #2302
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2302__YDE_4l6UFVU.wav extracted.
# rownum = 2302
# Processing Line #2303
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2303__YDgxxAdh18U.wav extracted.
# rownum = 2303
# Processing Line #2304
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2304__YDrIu6N9ppM.wav extracted.
# rownum = 2304
# Processing Line #2305
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2305__YEah_TfT_n8.wav extracted.
# rownum = 2305
# Processing Line #2306
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2306__yeIslDYvjSo.wav extracted.
# rownum = 2306
# Processing Line #2307
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2307__YeN2pW6TsFg.wav extracted.
# rownum = 2307
# Processing Line #2308
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2308__yhLjAy-Ev14.wav extracted.
# rownum = 2308
# Processing Line #2309
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2309__YI0n4mqPGlw.wav extracted.
# rownum = 2309
# Processing Line #2310
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2310__yigQ3wAUMiE.wav extracted.
# rownum = 2310
# Processing Line #2311
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2311__YiRKoloGiIA.wav extracted.
# rownum = 2311
# Processing Line #2312
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2312__YJLZYSeI6rc.wav extracted.
# rownum = 2312
# Processing Line #2313
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2313__yK8T_g0ar1c.wav extracted.
# rownum = 2313
# Processing Line #2314
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2314__yLS4aPktlKk.wav extracted.
# rownum = 2314
# Processing Line #2315
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2315__ylzNyQJ9AJk.wav extracted.
# rownum = 2315
# Processing Line #2316
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2316__yMQVvqazyJo.wav extracted.
# rownum = 2316
# Processing Line #2317
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2317__ymSPDcClbHk.wav extracted.
# rownum = 2317
# Processing Line #2318
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2318__ymwIXOaSCFo.wav extracted.
# rownum = 2318
# Processing Line #2319
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2319__YMy18Bharz4.wav extracted.
# rownum = 2319
# Processing Line #2320
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2320__YnIYMQNdcok.wav extracted.
# rownum = 2320
# Processing Line #2321
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2321__yO7dz8M8IEI.wav extracted.
# rownum = 2321
# Processing Line #2322
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2322__yoNzg8rWm7k.wav extracted.
# rownum = 2322
# Processing Line #2323
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2323__YoPDnV75Ttw.wav extracted.
# rownum = 2323
# Processing Line #2324
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2324__yOSmRAK0Xy4.wav extracted.
# rownum = 2324
# Processing Line #2325
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2325__Yp8IBDtKWeM.wav extracted.
# rownum = 2325
# Processing Line #2326
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2326__YPBX6hJ-m6I.wav extracted.
# rownum = 2326
# Processing Line #2327
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2327__ypCZGcr25go.wav extracted.
# rownum = 2327
# Processing Line #2328
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2328__yRbHPluG7Ck.wav extracted.
# rownum = 2328
# Processing Line #2329
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2329__Yrtfd9ajWqg.wav extracted.
# rownum = 2329
# Processing Line #2330
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2330__yRtQVxM3svk.wav extracted.
# rownum = 2330
# Processing Line #2331
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2331__ys3eVC2Pgwc.wav extracted.
# rownum = 2331
# Processing Line #2332
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2332__ys77k1s9eX0.wav extracted.
# rownum = 2332
# Processing Line #2333
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2333__ySQtj1JWnrc.wav extracted.
# rownum = 2333
# Processing Line #2334
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2334__yTzMPv7IdXQ.wav extracted.
# rownum = 2334
# Processing Line #2335
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2335__YWjGTilWbP8.wav extracted.
# rownum = 2335
# Processing Line #2336
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2336__YWN8hAQqVsc.wav extracted.
# rownum = 2336
# Processing Line #2337
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2337__ywTqqfXcvmk.wav extracted.
# rownum = 2337
# Processing Line #2338
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2338__yWu-PluvnWA.wav extracted.
# rownum = 2338
# Processing Line #2339
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2339__Yxc6ZXJwygE.wav extracted.
# rownum = 2339
# Processing Line #2340
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2340__YXTmzwpmQkU.wav extracted.
# rownum = 2340
# Processing Line #2341
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2341__Yyjmzg7Yc0U.wav extracted.
# rownum = 2341
# Processing Line #2342
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2342__yzQmvFyFM_g.wav extracted.
# rownum = 2342
# Processing Line #2343
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2343__Z0VcxU8iNKQ.wav extracted.
# rownum = 2343
# Processing Line #2344
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2344__z3WKXk_Vp7I.wav extracted.
# rownum = 2344
# Processing Line #2345
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2345__Z4Bup5dW0w4.wav extracted.
# rownum = 2345
# Processing Line #2346
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2346__Z5oJYll3RVg.wav extracted.
# rownum = 2346
# Processing Line #2347
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2347__z6MIi6_5Bh0.wav extracted.
# rownum = 2347
# Processing Line #2348
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2348__z7GzHi6OnDk.wav extracted.
# rownum = 2348
# Processing Line #2349
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2349__Z7LBlwKmYMU.wav extracted.
# rownum = 2349
# Processing Line #2350
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2350__Z_c2FYVrZKw.wav extracted.
# rownum = 2350
# Processing Line #2351
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2351__z_HP77rO4Y0.wav extracted.
# rownum = 2351
# Processing Line #2352
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2352__zABgudpv8qU.wav extracted.
# rownum = 2352
# Processing Line #2353
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2353__ZalOtRf7ZsU.wav extracted.
# rownum = 2353
# Processing Line #2354
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2354__zBSPxW8mVCA.wav extracted.
# rownum = 2354
# Processing Line #2355
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2355__zcaBSTlC9As.wav extracted.
# rownum = 2355
# Processing Line #2356
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2356__zCzHB2Gn-Ds.wav extracted.
# rownum = 2356
# Processing Line #2357
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2357__zD8wsOiEa2Y.wav extracted.
# rownum = 2357
# Processing Line #2358
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2358__zDrmjsaQynU.wav extracted.
# rownum = 2358
# Processing Line #2359
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2359__Ze1H7aKVtcM.wav extracted.
# rownum = 2359
# Processing Line #2360
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2360__ZeZ1-oQKmgg.wav extracted.
# rownum = 2360
# Processing Line #2361
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2361__ZFvaBZwzCI4.wav extracted.
# rownum = 2361
# Processing Line #2362
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2362__ZfX0KB1ffqM.wav extracted.
# rownum = 2362
# Processing Line #2363
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2363__zgmMZ51S45Q.wav extracted.
# rownum = 2363
# Processing Line #2364
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2364__zhAUkNhQ7uM.wav extracted.
# rownum = 2364
# Processing Line #2365
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2365__zhHLleIs8sE.wav extracted.
# rownum = 2365
# Processing Line #2366
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2366__ZIDLiWdVOtQ.wav extracted.
# rownum = 2366
# Processing Line #2367
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2367__zimraU2bmGw.wav extracted.
# rownum = 2367
# Processing Line #2368
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2368__ZjMWJAxh_XE.wav extracted.
# rownum = 2368
# Processing Line #2369
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2369__ZkKO6zUedsM.wav extracted.
# rownum = 2369
# Processing Line #2370
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2370__ZKuWf8tcT20.wav extracted.
# rownum = 2370
# Processing Line #2371
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2371__Zl-s5BQy71s.wav extracted.
# rownum = 2371
# Processing Line #2372
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2372__zlGEz6VulOg.wav extracted.
# rownum = 2372
# Processing Line #2373
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2373__ZM6FzZ9oecI.wav extracted.
# rownum = 2373
# Processing Line #2374
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2374__ZM675mAxQdA.wav extracted.
# rownum = 2374
# Processing Line #2375
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2375__Zm-IXJtxiDE.wav extracted.
# rownum = 2375
# Processing Line #2376
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2376__ZmDuPjd7owI.wav extracted.
# rownum = 2376
# Processing Line #2377
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2377__ZmqIh_OU1zY.wav extracted.
# rownum = 2377
# Processing Line #2378
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2378__ZMUt3UUAGAo.wav extracted.
# rownum = 2378
# Processing Line #2379
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2379__ZMY7fLy0Rxs.wav extracted.
# rownum = 2379
# Processing Line #2380
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2380__Zmz3YPTkwjs.wav extracted.
# rownum = 2380
# Processing Line #2381
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2381__ZO-b0xOybIw.wav extracted.
# rownum = 2381
# Processing Line #2382
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2382__ZoVIs72ONRA.wav extracted.
# rownum = 2382
# Processing Line #2383
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2383__Zpm6WcW854Q.wav extracted.
# rownum = 2383
# Processing Line #2384
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2384__ZPrYZHI-DPQ.wav extracted.
# rownum = 2384
# Processing Line #2385
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2385__ZPzD1vM7McM.wav extracted.
# rownum = 2385
# Processing Line #2386
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2386__zq8c_jVKhcY.wav extracted.
# rownum = 2386
# Processing Line #2387
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2387__zQY5ZUYM6IA.wav extracted.
# rownum = 2387
# Processing Line #2388
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2388__ZRbLlFERf-8.wav extracted.
# rownum = 2388
# Processing Line #2389
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2389__Zrrp4Axi0T8.wav extracted.
# rownum = 2389
# Processing Line #2390
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2390__ZrZ9tj6dHJI.wav extracted.
# rownum = 2390
# Processing Line #2391
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2391__ZSoJq5A-Q10.wav extracted.
# rownum = 2391
# Processing Line #2392
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2392__ZStFIvW_Vhs.wav extracted.
# rownum = 2392
# Processing Line #2393
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2393__ZsZRbxGjIWM.wav extracted.
# rownum = 2393
# Processing Line #2394
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2394__ZT2YHO4azfU.wav extracted.
# rownum = 2394
# Processing Line #2395
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2395__ZTANOzyOGoU.wav extracted.
# rownum = 2395
# Processing Line #2396
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2396__ZtPyLUkbWs4.wav extracted.
# rownum = 2396
# Processing Line #2397
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2397__ZudpJqLV7t4.wav extracted.
# rownum = 2397
# Processing Line #2398
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2398__ZuqBUqbtUys.wav extracted.
# rownum = 2398
# Processing Line #2399
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2399__zURNTTC3Oes.wav extracted.
# rownum = 2399
# Processing Line #2400
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2400__ZVADQamUCss.wav extracted.
# rownum = 2400
# Processing Line #2401
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2401__ZVImE0U-nZU.wav extracted.
# rownum = 2401
# Processing Line #2402
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2402__zVKfoTGG2nc.wav extracted.
# rownum = 2402
# Processing Line #2403
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2403__zvl4DmtdgdY.wav extracted.
# rownum = 2403
# Processing Line #2404
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2404__zvmTtzJkcu0.wav extracted.
# rownum = 2404
# Processing Line #2405
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2405__zvysRdYkZ9s.wav extracted.
# rownum = 2405
# Processing Line #2406
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2406__ZwpKviZyn8Y.wav extracted.
# rownum = 2406
# Processing Line #2407
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2407__zwyS3CFHd00.wav extracted.
# rownum = 2407
# Processing Line #2408
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2408__Zz74xjBKvmE.wav extracted.
# rownum = 2408
# Processing Line #2409
# features for D:/Sistemas de Informação/TCC/data/train/train_data\2409__Zzi9CvoIC0c.wav extracted.
# rownum = 2409
# Features of =  (2410, 60, 420)
# Labels of =  (2410, 1)
# Saved D:/Sistemas de Informação/TCC/data/train/train_data/features/_x.npy
# Saved D:/Sistemas de Informação/TCC/data/train/train_data/features/_y.npy

# %%
save_files(save_dir,features,labels)
# Out:
# Features of =  (2410, 60, 420)
# Labels of =  (2410, 1)
# Saved D:/Sistemas de Informação/TCC/data/train/train_data/features/_x.npy
# Saved D:/Sistemas de Informação/TCC/data/train/train_data/features/_y.npy

# %%
print(labels==1)
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-1-d44afdb611a2>", line 1, in <module>
#     print(labels==1)
#
# NameError: name 'labels' is not defined

# %%
files = librosa.util.find_files(path, ext=['wav']) 
files = np.asarray(files)
for y in files: 
    ec50 = librosa.load(y, sr = 16000,mono = True)   
    ec50 = ec50[0]

# %%
files = librosa.util.find_files(pathAudio, ext=['wav']) 
files = np.asarray(files)
for y in files: 
    data = librosa.load(y, sr = 16000,mono = True)   
    data = data[0]     
    librosa.display.waveplot(data)
